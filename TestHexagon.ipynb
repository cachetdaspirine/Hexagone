# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
cdict = {'blue':   ((0.0,  0.9,0.9),
                    (0.5,  0.4, 0.4),
                    (1.0,  0.1, 0.1)),

         'green': ((0.0,  0.5, 0.5),
                   (0.5 , 1, 1),
                   (1.0,  0.3, 0.3)),

         'alpha': ((0.0,  1, 1),
                   (0.5 , 0.8, 0.8),
                   (1.0,  1, 1)),

         'red':  ((0.0,  0.4, 0.4),
                   (0.5,  0.5, 0.5),
                   (1.0,  0.9,0.9)),
}
cm = LinearSegmentedColormap('my_colormap', cdict, 1024)

# %%
Data=np.loadtxt('aight.txt')
X1,X2,Y1,Y2,C0,C1=np.array([]),np.array([]),np.array([]),np.array([]),np.array([]),np.array([])
for ligne in Data:
    X1=np.append(X1,ligne[0])
    Y1=np.append(Y1,ligne[1])
    X2=np.append(X2,ligne[2])
    Y2=np.append(Y2,ligne[3])
    C0=np.append(C0,ligne[5])
    C1=np.append(C1,((ligne[2]-ligne[0])**2+(ligne[3]-ligne[1])**2)**0.5)
Colorlim=(-max(abs(C1-C0)),max(abs(C1-C0)))
XC=sum(X1)/X1.shape[0]
YC=sum(Y1)/Y1.shape[0]

# %%
# %matplotlib notebook
fig,ax=plt.subplots(figsize=(8,6))
plot=ax.quiver(X1,Y1,X2-X1,Y2-Y1,C1-C0,
             scale = 1.0,angles='xy',scale_units = 'xy',width = 0.002,minlength=0.,headlength=0.,
             headaxislength=0.,headwidth=0.,alpha=1,edgecolor='k',cmap=cm)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
Data.shape
# Out:
# (23, 6)

# %%
Data
# Out:
# array([[0.288989, 0.5005  , 0.288989, 0.5005  , 1.      , 0.9     ],
#        [0.288989, 0.5005  , 0.288989, 0.5005  , 1.      , 0.9     ],
#        [0.288989, 0.5005  , 0.288989, 0.5005  , 1.      , 0.9     ],
#        [0.288989, 0.5005  , 0.288989, 0.5005  , 1.      , 0.5774  ],
#        [0.288989, 0.5005  , 0.288989, 0.5005  , 1.      , 0.5774  ],
#        [0.288989, 0.5005  , 0.288989, 0.5005  , 1.      , 0.5774  ],
#        [0.288989, 0.5005  , 0.288989, 0.5005  , 1.      , 0.5774  ],
#        [0.288989, 0.5005  , 0.288989, 0.5005  , 1.      , 1.1     ],
#        [0.288989, 0.5005  , 0.288989, 0.5005  , 1.      , 0.5774  ],
#        [0.288989, 0.5005  , 0.288989, 0.5005  , 1.      , 0.5774  ],
#        [0.288989, 0.5005  , 0.288989, 0.5005  , 1.      , 1.1     ],
#        [0.288989, 0.5005  , 0.288989, 0.5005  , 1.      , 1.1     ],
#        [0.288989, 0.5005  , 0.288989, 0.5005  , 1.      , 1.1     ],
#        [0.288989, 0.5005  , 0.288989, 0.5005  , 1.      , 0.9     ],
#        [0.288989, 0.5005  , 0.288989, 0.5005  , 1.      , 0.5774  ],
#        [0.288989, 0.5005  , 0.288989, 0.5005  , 1.      , 0.5774  ],
#        [0.288989, 0.5005  , 0.288989, 0.5005  , 1.      , 0.5774  ],
#        [0.288989, 0.5005  , 0.288989, 0.5005  , 1.      , 1.1     ],
#        [0.288989, 0.5005  , 0.288989, 0.5005  , 1.      , 1.1     ],
#        [0.288989, 0.5005  , 0.288989, 0.5005  , 1.      , 0.9     ],
#        [0.288989, 0.5005  , 0.288989, 0.5005  , 1.      , 0.5774  ],
#        [0.288989, 0.5005  , 0.288989, 0.5005  , 1.      , 0.9     ],
#        [0.288989, 0.5005  , 0.288989, 0.5005  , 1.      , 0.5774  ]])

# %%
C1-C0
# Out:
# array([ 8.59552899e-03,  7.10632046e-05,  8.56723125e-03, -1.11022302e-16,
#         8.56723125e-03,  0.00000000e+00,  7.10632046e-05,  8.59552899e-03,
#         8.55253059e-03,  5.81426219e-05,  5.81426219e-05,  8.55253059e-03])
